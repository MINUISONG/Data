# %% [markdown]
# # Matplotlib
#
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show() #같이 출력되는 문자를 보기 싫다면 그래프만 보여주는 함수

# %% [markdown]
# # Title 설정

# %%
plt.plot(x,y)
plt.title('line graph')
# Out:
# Text(0.5, 1.0, 'line graph')

# %%
plt.plot(x,y)
plt.title('그래프') #한글로 쓰기 위해선 환경설정 필요
# Out:
# Text(0.5, 1.0, '그래프')

# %% [markdown]
# # 한글 폰트 설정

# %%
#폰트 디폴트 설정하면 좋은 것들
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' #맥 설정
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시, 마이너스 글자가 꺠지는거 방지

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist] #이름 부분만 확인
# Out:
# ['cmr10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmmi10',
#  'STIXSizeOneSym',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmsy10',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'DejaVu Serif Display',
#  'cmss10',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'cmex10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  '.SF Arabic Rounded',
#  'Noto Sans Bassa Vah',
#  'Hubballi',
#  'KufiStandardGK',
#  'BM Dohyeon',
#  'Waseem',
#  'Big Caslon',
#  'Noto Sans Imperial Aramaic',
#  'Noto Sans Modi',
#  'Gurmukhi Sangam MN',
#  '.SF Hebrew Rounded',
#  'Al Bayan',
# ...

# %%
plt.plot(x,y)
plt.title('그래프') #한글로 쓰기 위해선 환경설정 필요
# Out:
# Text(0.5, 1.0, '그래프')

# %%
plt.plot([-1,0,1], [-5,-2,2]) #음수도 환결설정 추가해줘야함

# %%
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시, 마이너스 글자가 꺠지는거 방지

# %%
plt.plot([-1,0,1], [-5,-2,2]) #음수도 환결설정 추가해줘야함
